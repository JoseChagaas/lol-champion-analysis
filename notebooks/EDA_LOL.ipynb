# %%
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Análise Exploratória LOL/050625_LoL_champion_data.csv", header=0) #Garante que a primear linha será o cabeçalho

# %%
df.shape
# Out:
# (172, 33)

# %%
df.head()
# Out:
#   Unnamed: 0     id  apiname                title  difficulty  herotype  \
# 0     Aatrox  266.0   Aatrox     the Darkin Blade           2   Fighter
# 1       Ahri  103.0     Ahri  the Nine-Tailed Fox           2      Mage
# 2      Akali   84.0    Akali   the Rogue Assassin           2  Assassin
# 3     Akshan  166.0   Akshan   the Rogue Sentinel           3  Marksman
# 4    Alistar   12.0  Alistar         the Minotaur           1      Tank
#
#     alttype    resource                                              stats  \
# 0      Tank  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...
# 1  Assassin        Mana  {'hp_base': 590, 'hp_lvl': 104, 'mp_base': 418...
# 2       NaN      Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 3  Assassin        Mana  {'hp_base': 630, 'hp_lvl': 107, 'mp_base': 350...
# 4   Support        Mana  {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...
#
#   rangetype        date         patch changes                      role  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'apiname', 'title', 'difficulty', 'herotype',
#        'alttype', 'resource', 'stats', 'rangetype', 'date', 'patch', 'changes',
#        'role', 'client_positions', 'external_positions', 'damage', 'toughness',
#        'control', 'mobility', 'utility', 'style', 'adaptivetype', 'be', 'rp',
#        'skill_i', 'skill_q', 'skill_w', 'skill_e', 'skill_r', 'skills',
#        'fullname', 'nickname'],
#       dtype='object')

# %%
#Linha de código para mostrar todas as colunas no .head()
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#   Unnamed: 0     id  apiname                title  difficulty  herotype  \
# 0     Aatrox  266.0   Aatrox     the Darkin Blade           2   Fighter
# 1       Ahri  103.0     Ahri  the Nine-Tailed Fox           2      Mage
# 2      Akali   84.0    Akali   the Rogue Assassin           2  Assassin
# 3     Akshan  166.0   Akshan   the Rogue Sentinel           3  Marksman
# 4    Alistar   12.0  Alistar         the Minotaur           1      Tank
#
#     alttype    resource                                              stats  \
# 0      Tank  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...
# 1  Assassin        Mana  {'hp_base': 590, 'hp_lvl': 104, 'mp_base': 418...
# 2       NaN      Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 3  Assassin        Mana  {'hp_base': 630, 'hp_lvl': 107, 'mp_base': 350...
# 4   Support        Mana  {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...
#
#   rangetype        date         patch changes                      role  \
# ...

# %%
#Filtra a coluna client_positions apenas com valor "Top"
df_top = df[df['client_positions'].apply(lambda x: 'Top' in x)]

# %%
df_top.head()
# Out:
#    Unnamed: 0     id  apiname                     title  difficulty  herotype  \
# 0      Aatrox  266.0   Aatrox          the Darkin Blade           2   Fighter
# 2       Akali   84.0    Akali        the Rogue Assassin           2  Assassin
# 5     Ambessa  799.0  Ambessa          Matriarch of War           3   Fighter
# 12     Aurora  893.0   Aurora  the Witch Between Worlds           2      Mage
# 21    Camille  164.0  Camille          the Steel Shadow           3   Fighter
#
#      alttype    resource                                              stats  \
# 0       Tank  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...
# 2        NaN      Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 5   Assassin      Energy  {'hp_base': 630, 'hp_lvl': 110, 'mp_base': 200...
# 12  Assassin        Mana  {'hp_base': 607, 'hp_lvl': 110, 'mp_base': 475...
# 21  Assassin        Mana  {'hp_base': 650, 'hp_lvl': 99, 'mp_base': 339,...
#
# ...

# %%
df.head()
# Out:
#   Unnamed: 0     id  apiname                title  difficulty  herotype  \
# 0     Aatrox  266.0   Aatrox     the Darkin Blade           2   Fighter
# 1       Ahri  103.0     Ahri  the Nine-Tailed Fox           2      Mage
# 2      Akali   84.0    Akali   the Rogue Assassin           2  Assassin
# 3     Akshan  166.0   Akshan   the Rogue Sentinel           3  Marksman
# 4    Alistar   12.0  Alistar         the Minotaur           1      Tank
#
#     alttype    resource                                              stats  \
# 0      Tank  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...
# 1  Assassin        Mana  {'hp_base': 590, 'hp_lvl': 104, 'mp_base': 418...
# 2       NaN      Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 3  Assassin        Mana  {'hp_base': 630, 'hp_lvl': 107, 'mp_base': 350...
# 4   Support        Mana  {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...
#
#   rangetype        date         patch changes                      role  \
# ...

# %%
#Filtra a coluna client_positions apenas com valor "Jungle"
df_jg = df[df['client_positions'].apply(lambda x: 'Jungle' in x)]
df_jg.head()
# Out:
#    Unnamed: 0     id  apiname                    title  difficulty herotype  \
# 6       Amumu   32.0    Amumu            the Sad Mummy           1     Tank
# 15   Bel'Veth  200.0  Belveth  the Empress of the Void           2  Fighter
# 17      Brand   63.0    Brand    the Burning Vengeance           2     Mage
# 19      Briar  233.0    Briar    the Restrained Hunger           2  Fighter
# 26      Diana  131.0    Diana        Scorn of the Moon           1  Fighter
#
#      alttype resource                                              stats  \
# 6    Support     Mana  {'hp_base': 685, 'hp_lvl': 94, 'mp_base': 285,...
# 15       NaN      NaN  {'hp_base': 610, 'hp_lvl': 99, 'mp_base': 0, '...
# 17   Support     Mana  {'hp_base': 570, 'hp_lvl': 105, 'mp_base': 469...
# 19  Assassin   Frenzy  {'hp_base': 625, 'hp_lvl': 95, 'mp_base': 0, '...
# 26  Assassin     Mana  {'hp_base': 640, 'hp_lvl': 109, 'mp_base': 375...
#
# ...

# %%
#Filtra a coluna client_positions apenas com os valores 'Middle'
df_mid = df[df['client_positions'].apply(lambda x: 'Middle' in x)]
df_mid.head()
# Out:
#   Unnamed: 0     id apiname                title  difficulty  herotype  \
# 1       Ahri  103.0    Ahri  the Nine-Tailed Fox           2      Mage
# 2      Akali   84.0   Akali   the Rogue Assassin           2  Assassin
# 3     Akshan  166.0  Akshan   the Rogue Sentinel           3  Marksman
# 7     Anivia   34.0  Anivia      the Cryophoenix           3      Mage
# 8      Annie    1.0   Annie       the Dark Child           1      Mage
#
#     alttype resource                                              stats  \
# 1  Assassin     Mana  {'hp_base': 590, 'hp_lvl': 104, 'mp_base': 418...
# 2       NaN   Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 3  Assassin     Mana  {'hp_base': 630, 'hp_lvl': 107, 'mp_base': 350...
# 7   Support     Mana  {'hp_base': 550, 'hp_lvl': 92, 'mp_base': 495,...
# 8   Support     Mana  {'hp_base': 560, 'hp_lvl': 96, 'mp_base': 418,...
#
#   rangetype        date                patch changes  \
# ...

# %%
#Função retorna True se 'Support' estiver presente no conjunto valor
def support(valor):
    return 'Support' in valor

#Aplica a função support em cada linha da coluna 'client_positions'
filter_sup = df['client_positions'].apply(support)

#Filtra o data frame com ajuda da variavel 'filter_sup'
df_sup = df[filter_sup]

df_sup.head()
# Out:
#     Unnamed: 0     id     apiname                    title  difficulty  \
# 4      Alistar   12.0     Alistar             the Minotaur           1
# 10        Ashe   22.0        Ashe         the Frost Archer           1
# 14        Bard  432.0        Bard  the Wandering Caretaker           3
# 16  Blitzcrank   53.0  Blitzcrank    the Great Steam Golem           1
# 17       Brand   63.0       Brand    the Burning Vengeance           2
#
#     herotype  alttype resource  \
# 4       Tank  Support     Mana
# 10  Marksman  Support     Mana
# 14   Support     Mage     Mana
# 16      Tank  Support     Mana
# 17      Mage  Support     Mana
#
#                                                 stats rangetype        date  \
# 4   {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...     Melee  2009-02-21
# 10  {'hp_base': 610, 'hp_lvl': 101, 'mp_base': 280...    Ranged  2009-02-21
# 14  {'hp_base': 630, 'hp_lvl': 103, 'mp_base': 350...    Ranged  2015-03-12
# ...

# %%
def adc(valor):
    return 'Bottom' in valor

filter_adc = df['client_positions'].apply(adc)

df_adc = df[filter_adc]
df_adc.head()
# Out:
#    Unnamed: 0     id   apiname                       title  difficulty  \
# 9    Aphelios  523.0  Aphelios  the Weapon of the Faithful           3
# 10       Ashe   22.0      Ashe            the Frost Archer           1
# 20    Caitlyn   51.0   Caitlyn     the Sheriff of Piltover           1
# 28     Draven  119.0    Draven    the Glorious Executioner           3
# 32     Ezreal   81.0    Ezreal       the Prodigal Explorer           1
#
#     herotype  alttype resource  \
# 9   Marksman      NaN     Mana
# 10  Marksman  Support     Mana
# 20  Marksman      NaN     Mana
# 28  Marksman      NaN     Mana
# 32  Marksman     Mage     Mana
#
#                                                 stats rangetype        date  \
# 9   {'hp_base': 600, 'hp_lvl': 102, 'mp_base': 348...    Ranged  2019-12-11
# 10  {'hp_base': 610, 'hp_lvl': 101, 'mp_base': 280...    Ranged  2009-02-21
# 20  {'hp_base': 580, 'hp_lvl': 107, 'mp_base': 315...    Ranged  2011-01-04
# ...

# %%
df_adc.shape
# Out:
# (27, 33)

# %%
df_top.shape
# Out:
# (49, 33)

# %%
df_jg.shape
# Out:
# (41, 33)

# %%
df_mid.shape
# Out:
# (42, 33)

# %%
df_sup.shape
# Out:
# (37, 33)

# %%
#Pegando quantidade de campeão por data frame
qtd_top = len(df_top)
qtd_jg = len(df_jg)
qtd_mid = len(df_mid)
qtd_sup = len(df_sup)
qtd_adc = len(df_adc)

# %%
print(qtd_top, qtd_jg, qtd_mid, qtd_sup, qtd_adc)
# Out:
# 49 41 42 37 27

# %%
lanes = ['Top', 'Jungle', 'Mid', 'Sup', 'ADC']
quantidades = [ qtd_top, qtd_jg, qtd_mid, qtd_sup, qtd_adc]

#Criando gráfico de barras QUANTIDADE X LANES
plt.figure(figsize=(8,5))
plt.bar(lanes, quantidades, color = 'skyblue')

#Títulos
plt.title('Campeões por Lane')
plt.xlabel('Lanes')
plt.ylabel('Quantidade')

plt.show()

# %%
#Calculando a média de dificuldades dos campeões de cada lane
media_top = df_top['difficulty'].mean()
media_jg = df_jg['difficulty'].mean()
media_mid = df_mid['difficulty'].mean()
media_sup = df_sup['difficulty'].mean()
media_adc = df_adc['difficulty'].mean()

#Criando gráfico de barras DIFICULDADE x LANES

lanes = ['Top', 'Jungle', 'Mid', 'Sup', 'ADC']
dificuldade = [ media_top, media_jg, media_mid, media_sup, media_adc]

plt.figure(figsize=(8,5))
plt.bar(lanes, dificuldade, color='skyblue')

#Títulos
plt.title('Média da Dificuldade de Campeão por Lane (1 a 3)')
plt.xlabel('Lanes')
plt.ylabel('Dificuldade')

plt.show()

# %%
df.head()
# Out:
#   Unnamed: 0     id  apiname                title  difficulty  herotype  \
# 0     Aatrox  266.0   Aatrox     the Darkin Blade           2   Fighter
# 1       Ahri  103.0     Ahri  the Nine-Tailed Fox           2      Mage
# 2      Akali   84.0    Akali   the Rogue Assassin           2  Assassin
# 3     Akshan  166.0   Akshan   the Rogue Sentinel           3  Marksman
# 4    Alistar   12.0  Alistar         the Minotaur           1      Tank
#
#     alttype    resource                                              stats  \
# 0      Tank  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...
# 1  Assassin        Mana  {'hp_base': 590, 'hp_lvl': 104, 'mp_base': 418...
# 2       NaN      Energy  {'hp_base': 600, 'hp_lvl': 119, 'mp_base': 200...
# 3  Assassin        Mana  {'hp_base': 630, 'hp_lvl': 107, 'mp_base': 350...
# 4   Support        Mana  {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...
#
#   rangetype        date         patch changes                      role  \
# ...

# %%
#Garante que o Python entenda os valores como data
df['date'] = pd.to_datetime(df['date'], errors="coerce")

# %%
#Criando uma nova coluna com o ano de lançamento de cada campeão
df['ano_lancamento'] = df['date'].dt.year

# %%
df.head(1)
# Out:
#   Unnamed: 0     id apiname             title  difficulty herotype alttype  \
# 0     Aatrox  266.0  Aatrox  the Darkin Blade           2  Fighter    Tank
#
#      resource                                              stats rangetype  \
# 0  Blood Well  {'hp_base': 650, 'hp_lvl': 114, 'mp_base': 0, ...     Melee
#
#         date patch changes            role client_positions  \
# 0 2013-06-13  V3.8  V25.11  {'Juggernaut'}          {'Top'}
#
#   external_positions  damage  toughness  control  mobility  utility  style  \
# 0            {'Top'}       3          3        2         2        2     20
#
#   adaptivetype    be   rp                     skill_i  \
# 0     Physical  2400  880  {1: 'Deathbringer Stance'}
#
#                                             skill_q                 skill_w  \
# 0  {1: 'The Darkin Blade', 2: 'The Darkin Blade 3'}  {1: 'Infernal Chains'}
#
#               skill_e             skill_r  \
# 0  {1: 'Umbral Dash'}  {1: 'World Ender'}
#
# ...

# %%
#Contando a quantidade de campeões por ano
campeoes_por_ano = df['ano_lancamento'].value_counts().sort_index()
print(campeoes_por_ano)
# Out:
# ano_lancamento
# 2009    42
# 2010    24
# 2011    24
# 2012    19
# 2013     8
# 2014     7
# 2015     5
# 2016     7
# 2017     5
# 2018     3
# 2019     5
# 2020     6
# 2021     4
# 2022     5
# 2023     4
# 2024     3
# 2025     1
# Name: count, dtype: int64

# %%
campeoes_por_ano.plot(kind='bar', color='skyblue')
plt.title("Número de Campeões por Ano de Lançamento")
plt.xlabel("Ano de Lançamento")
plt.ylabel("Número de Campeões")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle="--", alpha=1)
plt.tight_layout()
plt.show()
